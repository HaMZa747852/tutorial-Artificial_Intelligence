# %% [markdown]
# This is a simple example using Transfer Learning for an image recognition problem.

# %%
# General Libs
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
#from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load dataset

# %%
# Alguns parâmetros para leitura do dataset
im_shape = (299,299)

TRAINING_DIR = '../input/amazon-fruits-small/ds_frutas_am/train'
TEST_DIR = '../input/amazon-fruits-small/ds_frutas_am/test'

seed = 10

BATCH_SIZE = 16

# %%
#Using keras ImageGenerator and flow_from_directoty

# Image dataset without augmentation
#data_generator = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=0.2)
# With augmentation
data_generator = ImageDataGenerator(
        validation_split=0.2,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        preprocessing_function=preprocess_input,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')
val_data_generator = ImageDataGenerator(preprocessing_function=preprocess_input,validation_split=0.2)

# %%
# Generator para parte train
train_generator = data_generator.flow_from_directory(TRAINING_DIR, target_size=im_shape, shuffle=True, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE, subset="training")
# Generator para parte validação
validation_generator = val_data_generator.flow_from_directory(TRAINING_DIR, target_size=im_shape, shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE, subset="validation")

# Generator para dataset de teste
test_generator = ImageDataGenerator(preprocessing_function=preprocess_input)
test_generator = test_generator.flow_from_directory(TEST_DIR, target_size=im_shape, shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE)

nb_train_samples = train_generator.samples
nb_validation_samples = validation_generator.samples
nb_test_samples = test_generator.samples
classes = list(train_generator.class_indices.keys())
print('Classes: '+str(classes))
num_classes  = len(classes)
# Out:
# Found 72 images belonging to 6 classes.
# Found 18 images belonging to 6 classes.
# Found 30 images belonging to 6 classes.
# Classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %%
# Visualizando alguns exemplos do dataset por meio do Generator criado
plt.figure(figsize=(15,15))
for i in range(9):
    #gera subfigures
    plt.subplot(330 + 1 + i)
    batch = (train_generator.next()[0]+1)/2*255
    image = batch[0].astype('uint8')
    plt.imshow(image)
plt.show()

# %% [markdown]
# # Transfer Learning from a Deep Model

# %%
base_model = InceptionResNetV2(weights='imagenet',include_top=False, input_shape=(im_shape[0], im_shape[1], 3))

x = base_model.output
x = Flatten()(x)
x = Dense(100, activation='relu')(x)
predictions = Dense(num_classes, activation='softmax', kernel_initializer='random_uniform')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Freezing pretrained layers
base_model.trainable = False

optimizer = Adam()
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 6s 0us/step

# %%
epochs = 200

# Saving the best model
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='model.h5',
        monitor='val_loss', save_best_only=True, verbose=1),
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,verbose=1)
]

history = model.fit(
        train_generator,
        steps_per_epoch=nb_train_samples // BATCH_SIZE,
        epochs=epochs,
        callbacks = callbacks_list,
        validation_data=validation_generator,
        verbose = 1,
        validation_steps=nb_validation_samples // BATCH_SIZE)
# Out:
# Epoch 1/200
# 4/4 [==============================] - ETA: 0s - loss: 10.2168 - accuracy: 0.1964
# Epoch 00001: val_loss improved from inf to 6.16924, saving model to model.h5
# 4/4 [==============================] - 6s 1s/step - loss: 10.2168 - accuracy: 0.1964 - val_loss: 6.1692 - val_accuracy: 0.4375
# Epoch 2/200
# 4/4 [==============================] - ETA: 0s - loss: 4.3189 - accuracy: 0.3036
# Epoch 00002: val_loss improved from 6.16924 to 4.22832, saving model to model.h5
# 4/4 [==============================] - 3s 741ms/step - loss: 4.3189 - accuracy: 0.3036 - val_loss: 4.2283 - val_accuracy: 0.4375
# Epoch 3/200
# 4/4 [==============================] - ETA: 0s - loss: 2.0672 - accuracy: 0.4643
# Epoch 00003: val_loss improved from 4.22832 to 1.56247, saving model to model.h5
# 4/4 [==============================] - 3s 752ms/step - loss: 2.0672 - accuracy: 0.4643 - val_loss: 1.5625 - val_accuracy: 0.6250
# Epoch 4/200
# 4/4 [==============================] - ETA: 0s - loss: 1.2608 - accuracy: 0.6250
# Epoch 00004: val_loss improved from 1.56247 to 0.56501, saving model to model.h5
# 4/4 [==============================] - 4s 932ms/step - loss: 1.2608 - accuracy: 0.6250 - val_loss: 0.5650 - val_accuracy: 0.6875
# Epoch 5/200
# 4/4 [==============================] - ETA: 0s - loss: 0.7856 - accuracy: 0.7679
# Epoch 00005: val_loss improved from 0.56501 to 0.40618, saving model to model.h5
# 4/4 [==============================] - 3s 698ms/step - loss: 0.7856 - accuracy: 0.7679 - val_loss: 0.4062 - val_accuracy: 0.8125
# Epoch 6/200
# 4/4 [==============================] - ETA: 0s - loss: 0.7212 - accuracy: 0.7321
# Epoch 00006: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 264ms/step - loss: 0.7212 - accuracy: 0.7321 - val_loss: 0.7208 - val_accuracy: 0.6875
# Epoch 7/200
# 4/4 [==============================] - ETA: 0s - loss: 0.5720 - accuracy: 0.7857
# Epoch 00007: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 257ms/step - loss: 0.5720 - accuracy: 0.7857 - val_loss: 0.7290 - val_accuracy: 0.6875
# Epoch 8/200
# 4/4 [==============================] - ETA: 0s - loss: 0.5309 - accuracy: 0.7857
# Epoch 00008: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 261ms/step - loss: 0.5309 - accuracy: 0.7857 - val_loss: 0.6817 - val_accuracy: 0.7500
# Epoch 9/200
# 4/4 [==============================] - ETA: 0s - loss: 0.2977 - accuracy: 0.9107
# Epoch 00009: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 326ms/step - loss: 0.2977 - accuracy: 0.9107 - val_loss: 0.5416 - val_accuracy: 0.6875
# Epoch 10/200
# 4/4 [==============================] - ETA: 0s - loss: 0.2426 - accuracy: 0.9107
# Epoch 00010: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 253ms/step - loss: 0.2426 - accuracy: 0.9107 - val_loss: 0.6415 - val_accuracy: 0.7500
# Epoch 11/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1923 - accuracy: 0.9464
# Epoch 00011: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 306ms/step - loss: 0.1923 - accuracy: 0.9464 - val_loss: 0.7272 - val_accuracy: 0.7500
# Epoch 12/200
# 4/4 [==============================] - ETA: 0s - loss: 0.2174 - accuracy: 0.9286
# Epoch 00012: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 300ms/step - loss: 0.2174 - accuracy: 0.9286 - val_loss: 0.5566 - val_accuracy: 0.7500
# Epoch 13/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1711 - accuracy: 0.9464
# Epoch 00013: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 266ms/step - loss: 0.1711 - accuracy: 0.9464 - val_loss: 0.6227 - val_accuracy: 0.8125
# Epoch 14/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1506 - accuracy: 0.9464
# Epoch 00014: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 260ms/step - loss: 0.1506 - accuracy: 0.9464 - val_loss: 0.6601 - val_accuracy: 0.8125
# Epoch 15/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9821
# Epoch 00015: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0662 - accuracy: 0.9821 - val_loss: 0.7137 - val_accuracy: 0.7500
# Epoch 16/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9821
# Epoch 00016: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 276ms/step - loss: 0.0815 - accuracy: 0.9821 - val_loss: 0.7997 - val_accuracy: 0.7500
# Epoch 17/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9643
# Epoch 00017: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 252ms/step - loss: 0.1049 - accuracy: 0.9643 - val_loss: 0.8518 - val_accuracy: 0.7500
# Epoch 18/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0867 - accuracy: 0.9688
# Epoch 00018: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0867 - accuracy: 0.9688 - val_loss: 0.7785 - val_accuracy: 0.7500
# Epoch 19/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0706 - accuracy: 0.9688
# Epoch 00019: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0706 - accuracy: 0.9688 - val_loss: 0.6027 - val_accuracy: 0.7500
# Epoch 20/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1289 - accuracy: 0.9464
# Epoch 00020: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 306ms/step - loss: 0.1289 - accuracy: 0.9464 - val_loss: 0.5594 - val_accuracy: 0.8125
# Epoch 21/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0754 - accuracy: 0.9821
# Epoch 00021: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 309ms/step - loss: 0.0754 - accuracy: 0.9821 - val_loss: 0.5278 - val_accuracy: 0.8125
# Epoch 22/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9688
# Epoch 00022: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 370ms/step - loss: 0.1065 - accuracy: 0.9688 - val_loss: 0.5161 - val_accuracy: 0.6875
# Epoch 23/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9821
# Epoch 00023: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 332ms/step - loss: 0.0495 - accuracy: 0.9821 - val_loss: 0.5729 - val_accuracy: 0.6875
# Epoch 24/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9821
# Epoch 00024: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 259ms/step - loss: 0.1059 - accuracy: 0.9821 - val_loss: 0.4770 - val_accuracy: 0.8750
# Epoch 25/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 1.0000
# Epoch 00025: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0466 - accuracy: 1.0000 - val_loss: 0.4724 - val_accuracy: 0.8750
# Epoch 26/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1487 - accuracy: 0.9643
# Epoch 00026: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 294ms/step - loss: 0.1487 - accuracy: 0.9643 - val_loss: 0.5336 - val_accuracy: 0.7500
# Epoch 27/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 1.0000
# Epoch 00027: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 274ms/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.5404 - val_accuracy: 0.8125
# Epoch 28/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9821
# Epoch 00028: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 248ms/step - loss: 0.0459 - accuracy: 0.9821 - val_loss: 0.6616 - val_accuracy: 0.6250
# Epoch 29/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 1.0000
# Epoch 00029: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 264ms/step - loss: 0.0441 - accuracy: 1.0000 - val_loss: 0.7194 - val_accuracy: 0.6250
# Epoch 30/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9821
# Epoch 00030: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 325ms/step - loss: 0.0707 - accuracy: 0.9821 - val_loss: 0.5692 - val_accuracy: 0.7500
# Epoch 31/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0399 - accuracy: 0.9821
# Epoch 00031: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 306ms/step - loss: 0.0399 - accuracy: 0.9821 - val_loss: 0.5190 - val_accuracy: 0.8125
# Epoch 32/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9821
# Epoch 00032: val_loss did not improve from 0.40618
# 4/4 [==============================] - 1s 261ms/step - loss: 0.0341 - accuracy: 0.9821 - val_loss: 0.4831 - val_accuracy: 0.8125
# Epoch 33/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 1.0000
# Epoch 00033: val_loss improved from 0.40618 to 0.37279, saving model to model.h5
# 4/4 [==============================] - 3s 720ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.3728 - val_accuracy: 0.8125
# Epoch 34/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9821
# Epoch 00034: val_loss improved from 0.37279 to 0.30797, saving model to model.h5
# 4/4 [==============================] - 3s 825ms/step - loss: 0.0416 - accuracy: 0.9821 - val_loss: 0.3080 - val_accuracy: 0.8750
# Epoch 35/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 0.9821
# Epoch 00035: val_loss did not improve from 0.30797
# 4/4 [==============================] - 1s 265ms/step - loss: 0.0391 - accuracy: 0.9821 - val_loss: 0.3251 - val_accuracy: 0.8750
# Epoch 36/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9464
# Epoch 00036: val_loss improved from 0.30797 to 0.29832, saving model to model.h5
# 4/4 [==============================] - 3s 695ms/step - loss: 0.0859 - accuracy: 0.9464 - val_loss: 0.2983 - val_accuracy: 0.7500
# Epoch 37/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 1.0000
# Epoch 00037: val_loss improved from 0.29832 to 0.29105, saving model to model.h5
# 4/4 [==============================] - 3s 788ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.2910 - val_accuracy: 0.8750
# Epoch 38/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9821
# Epoch 00038: val_loss did not improve from 0.29105
# 4/4 [==============================] - 1s 271ms/step - loss: 0.0472 - accuracy: 0.9821 - val_loss: 0.2933 - val_accuracy: 0.8750
# Epoch 39/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 1.0000
# Epoch 00039: val_loss improved from 0.29105 to 0.25996, saving model to model.h5
# 4/4 [==============================] - 3s 777ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.2600 - val_accuracy: 0.9375
# Epoch 40/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 1.0000
# Epoch 00040: val_loss improved from 0.25996 to 0.25329, saving model to model.h5
# 4/4 [==============================] - 3s 689ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.2533 - val_accuracy: 0.8750
# Epoch 41/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9821
# Epoch 00041: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 307ms/step - loss: 0.0534 - accuracy: 0.9821 - val_loss: 0.3818 - val_accuracy: 0.7500
# Epoch 42/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1898 - accuracy: 0.9464
# Epoch 00042: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1898 - accuracy: 0.9464 - val_loss: 0.2667 - val_accuracy: 0.8750
# Epoch 43/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1039 - accuracy: 0.9531
# Epoch 00043: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 314ms/step - loss: 0.1039 - accuracy: 0.9531 - val_loss: 0.4264 - val_accuracy: 0.8125
# Epoch 44/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9643
# Epoch 00044: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 271ms/step - loss: 0.0760 - accuracy: 0.9643 - val_loss: 0.9674 - val_accuracy: 0.6875
# Epoch 45/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9643
# Epoch 00045: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 269ms/step - loss: 0.0457 - accuracy: 0.9643 - val_loss: 1.1345 - val_accuracy: 0.6875
# Epoch 46/200
# 4/4 [==============================] - ETA: 0s - loss: 0.3388 - accuracy: 0.8929
# Epoch 00046: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 304ms/step - loss: 0.3388 - accuracy: 0.8929 - val_loss: 0.7424 - val_accuracy: 0.8750
# Epoch 47/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9821
# Epoch 00047: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 270ms/step - loss: 0.0463 - accuracy: 0.9821 - val_loss: 0.4724 - val_accuracy: 0.7500
# Epoch 48/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 0.9821
# Epoch 00048: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 268ms/step - loss: 0.1268 - accuracy: 0.9821 - val_loss: 0.3864 - val_accuracy: 0.7500
# Epoch 49/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 1.0000
# Epoch 00049: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.3118 - val_accuracy: 0.9375
# Epoch 50/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9821
# Epoch 00050: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0250 - accuracy: 0.9821 - val_loss: 0.5108 - val_accuracy: 0.8750
# Epoch 51/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 1.0000
# Epoch 00051: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 263ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.7284 - val_accuracy: 0.8750
# Epoch 52/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 1.0000
# Epoch 00052: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 319ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.8579 - val_accuracy: 0.8125
# Epoch 53/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 1.0000
# Epoch 00053: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 252ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.7123 - val_accuracy: 0.8750
# Epoch 54/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 1.0000
# Epoch 00054: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 354ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.5253 - val_accuracy: 0.7500
# Epoch 55/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0949 - accuracy: 0.9643
# Epoch 00055: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 256ms/step - loss: 0.0949 - accuracy: 0.9643 - val_loss: 0.5785 - val_accuracy: 0.7500
# Epoch 56/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 1.0000
# Epoch 00056: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 263ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.8551 - val_accuracy: 0.7500
# Epoch 57/200
# 4/4 [==============================] - ETA: 0s - loss: 0.2843 - accuracy: 0.9464
# Epoch 00057: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 366ms/step - loss: 0.2843 - accuracy: 0.9464 - val_loss: 0.5153 - val_accuracy: 0.8750
# Epoch 58/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 00058: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 266ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.5144 - val_accuracy: 0.8750
# Epoch 59/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 1.0000
# Epoch 00059: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.6124 - val_accuracy: 0.7500
# Epoch 60/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9821
# Epoch 00060: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 254ms/step - loss: 0.0324 - accuracy: 0.9821 - val_loss: 0.5494 - val_accuracy: 0.8125
# Epoch 61/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0492 - accuracy: 0.9688
# Epoch 00061: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0492 - accuracy: 0.9688 - val_loss: 0.5010 - val_accuracy: 0.8125
# Epoch 62/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 00062: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4787 - val_accuracy: 0.8750
# Epoch 63/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00063: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 250ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.6232 - val_accuracy: 0.8750
# Epoch 64/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 00064: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 348ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.7125 - val_accuracy: 0.8750
# Epoch 65/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 00065: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 252ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.6105 - val_accuracy: 0.8750
# Epoch 66/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 00066: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 262ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.5277 - val_accuracy: 0.8125
# Epoch 67/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 00067: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 253ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.4489 - val_accuracy: 0.8125
# Epoch 68/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00068: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4406 - val_accuracy: 0.8750
# Epoch 69/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 1.0000
# Epoch 00069: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 244ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.3602 - val_accuracy: 0.8750
# Epoch 70/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9821
# Epoch 00070: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 250ms/step - loss: 0.0201 - accuracy: 0.9821 - val_loss: 0.3269 - val_accuracy: 0.8125
# Epoch 71/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00071: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 353ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.3653 - val_accuracy: 0.8750
# Epoch 72/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 00072: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 249ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.4214 - val_accuracy: 0.9375
# Epoch 73/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 1.0000
# Epoch 00073: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 338ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.4134 - val_accuracy: 0.8750
# Epoch 74/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 1.0000
# Epoch 00074: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 273ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.4267 - val_accuracy: 0.8125
# Epoch 75/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 1.0000
# Epoch 00075: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.5536 - val_accuracy: 0.7500
# Epoch 76/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9643
# Epoch 00076: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 260ms/step - loss: 0.0488 - accuracy: 0.9643 - val_loss: 0.2970 - val_accuracy: 0.8750
# Epoch 77/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9821
# Epoch 00077: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 251ms/step - loss: 0.0290 - accuracy: 0.9821 - val_loss: 0.4524 - val_accuracy: 0.8750
# Epoch 78/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0788 - accuracy: 0.9531
# Epoch 00078: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 351ms/step - loss: 0.0788 - accuracy: 0.9531 - val_loss: 0.3182 - val_accuracy: 0.8750
# Epoch 79/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9821
# Epoch 00079: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 264ms/step - loss: 0.0249 - accuracy: 0.9821 - val_loss: 0.6113 - val_accuracy: 0.7500
# Epoch 80/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9821
# Epoch 00080: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 256ms/step - loss: 0.0313 - accuracy: 0.9821 - val_loss: 0.4986 - val_accuracy: 0.8125
# Epoch 81/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1990 - accuracy: 0.9643
# Epoch 00081: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1990 - accuracy: 0.9643 - val_loss: 0.6111 - val_accuracy: 0.8750
# Epoch 82/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1578 - accuracy: 0.9821
# Epoch 00082: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 252ms/step - loss: 0.1578 - accuracy: 0.9821 - val_loss: 1.0877 - val_accuracy: 0.7500
# Epoch 83/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 1.0000
# Epoch 00083: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 252ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 1.4883 - val_accuracy: 0.6875
# Epoch 84/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 1.0000
# Epoch 00084: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 1.3466 - val_accuracy: 0.7500
# Epoch 85/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 00085: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 317ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.9837 - val_accuracy: 0.6875
# Epoch 86/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 00086: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 262ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.8439 - val_accuracy: 0.7500
# Epoch 87/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 00087: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.8220 - val_accuracy: 0.8125
# Epoch 88/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0986 - accuracy: 0.9844
# Epoch 00088: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0986 - accuracy: 0.9844 - val_loss: 0.9330 - val_accuracy: 0.6875
# Epoch 89/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 00089: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 251ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.2592 - val_accuracy: 0.6875
# Epoch 90/200
# 4/4 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9821
# Epoch 00090: val_loss did not improve from 0.25329
# 4/4 [==============================] - 1s 244ms/step - loss: 0.0361 - accuracy: 0.9821 - val_loss: 0.7980 - val_accuracy: 0.6875
# Epoch 00090: early stopping

# %%
#Vamos ver como foi o treino?
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs_x = range(1, len(loss_values) + 1)
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
plt.plot(epochs_x, loss_values, 'bo', label='Training loss')
plt.plot(epochs_x, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
#plt.legend()
plt.subplot(2,1,2)
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
plt.plot(epochs_x, acc_values, 'bo', label='Training acc')
plt.plot(epochs_x, val_acc_values, 'b', label='Validation acc')
#plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
# Load the best saved model
model = load_model('model.h5')

# %%
#model.summary()

# %%
# Using the validation dataset
score = model.evaluate_generator(validation_generator)
print('Val loss:', score[0])
print('Val accuracy:', score[1])
# Out:
# Val loss: 0.24665743112564087
# Val accuracy: 0.8888888955116272

# %%
# Using the test dataset
score = model.evaluate_generator(test_generator)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.5627443790435791
# Test accuracy: 0.7666666507720947

# %%
import itertools

#Plot the confusion matrix. Set Normalize = True/False
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Some reports
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

#Confution Matrix and Classification Report
Y_pred = model.predict_generator(test_generator)#, nb_test_samples // BATCH_SIZE, workers=1)
y_pred = np.argmax(Y_pred, axis=1)
target_names = classes

#Confution Matrix
cm = confusion_matrix(test_generator.classes, y_pred)
plot_confusion_matrix(cm, target_names, normalize=False, title='Confusion Matrix')
print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#         acai       1.00      0.40      0.57         5
#      cupuacu       0.80      0.80      0.80         5
#     graviola       1.00      1.00      1.00         5
#      guarana       0.80      0.80      0.80         5
#      pupunha       0.83      1.00      0.91         5
#       tucuma       0.43      0.60      0.50         5
#
#     accuracy                           0.77        30
#    macro avg       0.81      0.77      0.76        30
# weighted avg       0.81      0.77      0.76        30
